# %% [markdown]
# <a href="https://colab.research.google.com/github/justynigam/AIML/blob/main/NLP_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
import nltk
import re
from nltk.chat.util import Chat , reflections

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pairs = [
    [r"hi|hello" , ["Hell0 how can i help you ?" ,
                    "Hi there , how can i help you ?"]],
    [r"tell me a joke" , ["My grandfather has the heart of a lion and a lifetime ban from the local zoo."]]

]

# %%
class RuleBasedChatbot:
  def __init__(self , pairs):
    self.chat = Chat(pairs , reflections)
  def respond(self, user_input):
    return self.chat.respond(user_input)

# %%
def chat_with_bot():
  print("Hell0 , I am your chatbot !")
  while True:
    user_input = input("You: ")
    if user_input.lower() == 'bye':
      print("Chatbot: Goodbye! Have a nice day!")
      break
    response = chatbot.respond(user_input)
    print(f"Chatbot: {response}")

# %%
chatbot = RuleBasedChatbot(pairs)
chat_with_bot()
# Out:
# Hell0 , I am your chatbot !
# You: Hyy
# Chatbot: None
# You: tell me a joke
# Chatbot: My grandfather has the heart of a lion and a lifetime ban from the local zoo.
# You: tell me some joke
# Chatbot: None
# You: bye
# Chatbot: Goodbye! Have a nice day!
